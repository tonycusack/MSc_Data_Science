# %%
# imports
import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPool2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense, BatchNormalization
import matplotlib.pyplot as plt 
import sklearn.model_selection
from sklearn.model_selection import train_test_split
from random import random, shuffle
from sklearn.metrics import accuracy_score
from python_speech_features import mfcc
from braindecode.models import Deep4Net
import antropy
import sys
from scipy import integrate, stats
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsRegressor
from python_speech_features import mfcc
from scipy import spatial

from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
def tran(x, label1):
    if x == label1:
        return 1
    else:
        return 0

def get_data(type_of_data = 'imagined', subject_num = 1):
    '''Gets the data from the directory given the type of data
    and which subject to get it from. Returns an array (raw_eeg, labels)'''
    raw_eeg, all_labels = np.genfromtxt(f'{type_of_data}/labelled/{type_of_data}{subject_num}-labelled.csv', delimiter=',', dtype='float')[1:, 0:14], np.genfromtxt(f'{type_of_data}/labelled/{type_of_data}{subject_num}-labelled.csv', delimiter=',', dtype='str')[1::256, -1]
    raw_eeg = raw_eeg.reshape(1000, 256, 14)
    return raw_eeg, all_labels

# %%
def mean(x):
	return np.mean(x)

def absmean(x):
	return np.mean(np.abs(x))

def maximum(x):
	return np.max(x)

def absmax(x):
	return np.max(np.abs(x))

def minimum(x):
	return np.min(x)

def absmin(x):
	return np.min(np.abs(x)) 

def minplusmax(x):
	return np.max(x) + np.min(x)

def maxminusmin(x):
	return np.max(x) - np.min(x)

def curvelength(x):
	cl = 0
	for i in range(x.shape[0]-1):
		cl += abs(x[i]-x[i+1])
	return cl

def energy(x):
	return np.sum(np.multiply(x,x))

def nonlinear_energy(x):
	# NLE(x[n]) = x**2[n] - x[n+1]*x[n-1]
	x_squared = x[1:-1]**2
	subtrahend = x[2:]*x[:-2]
	return np.sum(x_squared-subtrahend)
	

def spec_entropy(x):
	return antropy.spectral_entropy(x, 128,method="welch",normalize=True)

def integral(x):
	return integrate.simps(x)

def stddeviation(x):
	return np.std(x)

def variance(x):
	return np.var(x)

def skew(x):
	return stats.skew(x)

def kurtosis(x):
	return stats.kurtosis(x)

def get_mfcc(x):
	return mfcc(x)


#doesn't contain EHF since that must be added later
funclist = [mean,absmean,maximum,absmax,minimum,absmin,minplusmax,maxminusmin,curvelength,energy,nonlinear_energy, integral,stddeviation,variance,skew,np.sum,spec_entropy, kurtosis] # , sample_entropy, perm_entropy, svd_entropy, app_entropy,petrosian, katz, higuchi, rootmeansquare]

# %%
def binary_split(data, labels, label1, label2):
    new_features, new_labels = data[(np.array(labels) == label1) + (np.array(labels) == label2)].astype('float32'), np.array(labels)[(np.array(labels) == label1) + (np.array(labels) == label2)]
    new_labels1 = [tran(x, label1) for x in new_labels]
    return new_features, new_labels1

# %%
def get_windows(raw_eeg, all_labels, raw = False):
    '''Gets the windows for our eeg data, 15 windows per epoch, length 32 windows. EEG data must be split binary.
    Returns the windowed data, the labels for each window and the feature array, and the labels for each feature array'''
    if raw == True:
        raw_eeg = raw_eeg.reshape(len(all_labels), 256, 14)
        labelled_data = []
        feature_array = []
        all_windows = []
        window_labels = []
        for i in range(raw_eeg.shape[0]):
            epoch = raw_eeg[i]
            label = all_labels[i]
            for j in range(15):
                window = np.array(epoch[(j * 16):((j + 2)*16)])
                all_windows.append(window)
                window_labels.append(label)

        return np.array(all_windows), window_labels

    else:
        raw_eeg = raw_eeg.reshape(len(all_labels), 256, 14)
        labelled_data = []
        feature_array = []
        for i in range(raw_eeg.shape[0]):
            epoch = raw_eeg[i]
            label = all_labels[i]
            windowed_data = []
            for j in range(15):
                window = np.array(epoch[(j * 16):((j + 2)*16)])
                outvec = np.zeros((len(funclist), window.shape[1]))
                for i, f in enumerate(funclist):
                    # print('applying {}'.format(f.__name__))
                    for col in range(window.shape[1]):
                        outvec[i, col] = f(window[:, col])
                outvec = outvec.reshape(-1)
                windowed_data.append(outvec)

            # 1-> 5 ... 11 -> 15
            for k in range(11):
                feature_array.append(np.stack(windowed_data[(k):(k+5)]))
                labelled_data.append(label)

        feature_array = np.array(feature_array)
        return feature_array, np.array(labelled_data)

# %%
label_pairs = [('goose', 'moose'), ('moose', 'spruce'),
                ('moose', 'caterpillar'), ('juice', 'waterfowl'),
                ('hedgehog', 'goose'), ('night', 'knight'), ('date', 'juice'), 
                ('hedgehog', 'waterfowl'), ('juice', 'ambassador')]

kfold = sklearn.model_selection.StratifiedKFold(n_splits = 5, shuffle = True, random_state=1)

# %%
# knn
parameters = {"n_neighbors": range(50, 200)}
kfold = sklearn.model_selection.StratifiedKFold(n_splits = 5, shuffle = True, random_state=1)
pca = PCA(0.95)
# function to import data and divide
def knn_dist_test(data, labels, label1, label2):
    data = data.reshape(1000, 256, 14)
   
    feats, labs = binary_split(data, labels, label1, label2)
    labs = np.array(labs)

    feats = feats.reshape(feats.shape[0], feats.shape[1] * feats.shape[2])
    val_accuracies = []
    for train_ind, val_ind in list(kfold.split(feats, labs)):
        feats_train, ft_labels = get_windows(feats[train_ind], labs[train_ind])
        feats_val, fv_labels = get_windows(feats[val_ind], labs[val_ind])

        feats_train = feats_train.reshape(feats_train.shape[0], feats_train.shape[1] * feats_train.shape[2])
        feats_val = feats_val.reshape(feats_val.shape[0], feats_val.shape[1] * feats_val.shape[2])
        #standardize now...
        feats_train = np.nan_to_num(feats_train)
        feats_val = np.nan_to_num(feats_val)
        feats_train, feats_val = StandardScaler().fit_transform(feats_train), StandardScaler().fit_transform(feats_val)
        # perform pca on training features
        pca.fit(feats_train)
        feats_train, feats_val = pca.transform(feats_train), pca.transform(feats_val)

        
        gridsearch = GridSearchCV(KNeighborsClassifier(), parameters)
        gridsearch.fit(feats_train, ft_labels)
        # gridsearch = KNeighborsClassifier(n_neighbors=95)
        # gridsearch.fit(feats_train, ft_labels)
        #predict our test set and record a score
        preds = [np.round(i) for i in gridsearch.predict(feats_val)]
        val_accuracies.append(accuracy_score(fv_labels, preds))

    print('KNN Binary classification between {} and {} for subject {}, {}'.format(label1, label2, subject_num, data_type))
    print('================================================================================================')
    print('10 fold Cross-validated accuracy: {} +- {}'.format(np.mean(val_accuracies), np.std(val_accuracies)))
    print()
    return 


for subject_num in range(1, 9):
    for data_type in ['imagined', 'inner']:
        print('Subject {}, {}'.format(subject_num, data_type))
        data, labels = get_data(data_type, subject_num)
        for label1, label2 in label_pairs:
            knn_dist_test(data, labels, label1, label2)
# Out:
# Subject 1, imagined
# KNN Binary classification between goose and moose for subject 1, imagined
# ================================================================================================
# 10 fold Cross-validated accuracy: 0.5663636363636363 +- 0.04967664033568819
#
# KNN Binary classification between moose and spruce for subject 1, imagined
# ================================================================================================
# 10 fold Cross-validated accuracy: 0.511818181818182 +- 0.05163444298604701
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\stims\experiments\knn.ipynb Cell 9 in <cell line: 41>()
#      <a href='vscode-notebook-cell:/c%3A/stims/experiments/knn.ipynb#W0sZmlsZQ%3D%3D?line=43'>44</a> data, labels = get_data(data_type, subject_num)
#      <a href='vscode-notebook-cell:/c%3A/stims/experiments/knn.ipynb#W0sZmlsZQ%3D%3D?line=44'>45</a> for label1, label2 in label_pairs:
# ---> <a href='vscode-notebook-cell:/c%3A/stims/experiments/knn.ipynb#W0sZmlsZQ%3D%3D?line=45'>46</a>     knn_dist_test(data, labels, label1, label2)
#
# c:\stims\experiments\knn.ipynb Cell 9 in knn_dist_test(data, labels, label1, label2)
#      <a href='vscode-notebook-cell:/c%3A/stims/experiments/knn.ipynb#W0sZmlsZQ%3D%3D?line=11'>12</a> val_accuracies = []
#      <a href='vscode-notebook-cell:/c%3A/stims/experiments/knn.ipynb#W0sZmlsZQ%3D%3D?line=12'>13</a> for train_ind, val_ind in list(kfold.split(feats, labs)):
# ---> <a href='vscode-notebook-cell:/c%3A/stims/experiments/knn.ipynb#W0sZmlsZQ%3D%3D?line=13'>14</a>     feats_train, ft_labels = get_windows(feats[train_ind], labs[train_ind])
#      <a href='vscode-notebook-cell:/c%3A/stims/experiments/knn.ipynb#W0sZmlsZQ%3D%3D?line=14'>15</a>     feats_val, fv_labels = get_windows(feats[val_ind], labs[val_ind])
#      <a href='vscode-notebook-cell:/c%3A/stims/experiments/knn.ipynb#W0sZmlsZQ%3D%3D?line=16'>17</a>     feats_train = feats_train.reshape(feats_train.shape[0], feats_train.shape[1] * feats_train.shape[2])
#
# c:\stims\experiments\knn.ipynb Cell 9 in get_windows(raw_eeg, all_labels, raw)
#      <a href='vscode-notebook-cell:/c%3A/stims/experiments/knn.ipynb#W0sZmlsZQ%3D%3D?line=30'>31</a> for i, f in enumerate(funclist):
#      <a href='vscode-notebook-cell:/c%3A/stims/experiments/knn.ipynb#W0sZmlsZQ%3D%3D?line=31'>32</a>     # print('applying {}'.format(f.__name__))
#      <a href='vscode-notebook-cell:/c%3A/stims/experiments/knn.ipynb#W0sZmlsZQ%3D%3D?line=32'>33</a>     for col in range(window.shape[1]):
# ---> <a href='vscode-notebook-cell:/c%3A/stims/experiments/knn.ipynb#W0sZmlsZQ%3D%3D?line=33'>34</a>         outvec[i, col] = f(window[:, col])
#      <a href='vscode-notebook-cell:/c%3A/stims/experiments/knn.ipynb#W0sZmlsZQ%3D%3D?line=34'>35</a> outvec = outvec.reshape(-1)
#      <a href='vscode-notebook-cell:/c%3A/stims/experiments/knn.ipynb#W0sZmlsZQ%3D%3D?line=35'>36</a> windowed_data.append(outvec)
#
# c:\stims\experiments\knn.ipynb Cell 9 in maximum(x)
#       <a href='vscode-notebook-cell:/c%3A/stims/experiments/knn.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a> def maximum(x):
# ----> <a href='vscode-notebook-cell:/c%3A/stims/experiments/knn.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a> 	return np.max(x)
#
# File <__array_function__ internals>:5, in amax(*args, **kwargs)
#
# File c:\Users\tonyc\anaconda3\envs\tensorflow\lib\site-packages\numpy\core\fromnumeric.py:2705, in amax(a, axis, out, keepdims, initial, where)
#    2589 @array_function_dispatch(_amax_dispatcher)
#    2590 def amax(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2591          where=np._NoValue):
#    2592     """
#    2593     Return the maximum of an array or maximum along an axis.
#    2594
#    (...)
#    2703     5
#    2704     """
# -> 2705     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2706                           keepdims=keepdims, initial=initial, where=where)
#
# File c:\Users\tonyc\anaconda3\envs\tensorflow\lib\site-packages\numpy\core\fromnumeric.py:87, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84         else:
#      85             return reduction(axis=axis, out=out, **passkwargs)
# ---> 87 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %%
def L4(x, y):
    return (np.sum((x - y)**4))**(1 / 4)

def L2(x, y):
    return (np.sum((x - y)**2))**(1 / 2)

def L3(x, y):
    return (np.sum((x - y)**3))**(1 / 3)

def chi2_distance(x, y):
 
    # compute the chi-squared distance using above formula
    chi = 0.5 * np.sum(((x - y) ** 2) / (x + y))
 
    return chi

def corr_coef(x, y):
    return 1 - np.corrcoef(x, y)[0, 1]

def spatial_dist(x, y):
    return spatial.distance.cosine(x, y)

funclist2 = [L4, L2, L3, chi2_distance, corr_coef, spatial_dist]

# %%
knn_metric_accs = np.zeros((4, 2, 9, 6))
knn_metric_stds = np.zeros((4, 2, 9, 6))
pca = PCA(0.95)
parameters = {"n_neighbors": range(90, 100)}

for subject_num in [5,6,7,8]:
    for d, data_type in enumerate(['imagined', 'inner']):
        data, labels = get_data(data_type, subject_num)
        for l ,(label1, label2) in enumerate(label_pairs):
            X, y = binary_split(data, labels, label1, label2)
            y = np.array(y)
            print('================================================================================================')
            print('5 fold Cross-validated accuracies KNN Binary classification between {} and {} for subject {}, {}'.format(label1, label2, subject_num, data_type))
            print('-------------------------------------------------------------------------')
            for f, func in enumerate(funclist2):
                val_accuracies = []
                for train_ind, val_ind in list(kfold.split(X, y)):
                    train_feats, train_labels = get_windows(X[train_ind], y[train_ind])
                    val_feats, val_labels = get_windows(X[val_ind], y[val_ind])

                    feats_train = train_feats.reshape(train_feats.shape[0], train_feats.shape[1] * train_feats.shape[2])
                    feats_val = val_feats.reshape(val_feats.shape[0], val_feats.shape[1] * val_feats.shape[2])
                    #standardize now...
                    feats_train = np.nan_to_num(feats_train)
                    feats_val = np.nan_to_num(feats_val)
                    feats_train, feats_val = StandardScaler().fit_transform(feats_train), StandardScaler().fit_transform(feats_val)
                    # perform pca on training features
                    pca.fit(feats_train)
                    feats_train, feats_val = pca.transform(feats_train), pca.transform(feats_val)

                    gridsearch = KNeighborsClassifier(metric=func)
                    gridsearch.fit(feats_train, train_labels)
                    # gridsearch = GridSearchCV(KNeighborsClassifier(metric = func), parameters)
                    # gridsearch.fit(feats_train, train_labels)
                    #predict our test set and record a score
                    preds = [np.round(i) for i in gridsearch.predict(feats_val)]
                    val_accuracies.append(accuracy_score(val_labels, preds))
                    # print('.')

                knn_metric_accs[subject_num - 5][d][l][f] +=  np.mean(val_accuracies)
                knn_metric_stds[subject_num - 5][d][l][f] +=  np.std(val_accuracies)
                print('Distance metric: {}, Accuracy +- sd: {} +- {}'.format(func.__name__, np.mean(val_accuracies), np.std(val_accuracies)))
                print()
# Out:
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between goose and moose for subject 5, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5027272727272727 +- 0.07287485026847666
#
# Distance metric: L2, Accuracy +- sd: 0.5154545454545454 +- 0.0817474441686049
#
# Distance metric: L3, Accuracy +- sd: 0.5136363636363637 +- 0.04954336943068622
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5036363636363637 +- 0.027783103254429294
#
# Distance metric: corr_coef, Accuracy +- sd: 0.4763636363636364 +- 0.08731059784394885
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.48 +- 0.08280216390353236
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between moose and spruce for subject 5, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5990909090909091 +- 0.027783103254429318
#
# Distance metric: L2, Accuracy +- sd: 0.5818181818181818 +- 0.041857688848077584
#
# Distance metric: L3, Accuracy +- sd: 0.5363636363636363 +- 0.02170424797511513
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.49363636363636365 +- 0.02310593641297971
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5536363636363636 +- 0.04277560129461304
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5554545454545454 +- 0.04018552019145517
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between moose and caterpillar for subject 5, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.62 +- 0.05367487061500187
#
# Distance metric: L2, Accuracy +- sd: 0.5972727272727273 +- 0.0641279712310851
#
# Distance metric: L3, Accuracy +- sd: 0.5554545454545454 +- 0.01661424262045186
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.44909090909090904 +- 0.018938787869090593
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5818181818181818 +- 0.04653266869843536
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5790909090909091 +- 0.0424069228716022
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between juice and waterfowl for subject 5, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5581818181818183 +- 0.07937774528342936
#
# Distance metric: L2, Accuracy +- sd: 0.5572727272727274 +- 0.07466730617593113
#
# Distance metric: L3, Accuracy +- sd: 0.5236363636363637 +- 0.04028821782938243
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.48636363636363644 +- 0.039834367818557544
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5372727272727273 +- 0.01661424262045186
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5318181818181819 +- 0.017486712783337594
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between hedgehog and goose for subject 5, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.49727272727272726 +- 0.04711512189036342
#
# Distance metric: L2, Accuracy +- sd: 0.5209090909090909 +- 0.057539063267078756
#
# Distance metric: L3, Accuracy +- sd: 0.49727272727272726 +- 0.03979285205134415
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.4927272727272728 +- 0.034688698233343494
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5190909090909092 +- 0.09165151389911681
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.519090909090909 +- 0.08466755601363674
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between night and knight for subject 5, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.45636363636363636 +- 0.09379950483578266
#
# Distance metric: L2, Accuracy +- sd: 0.45727272727272733 +- 0.10470738447519527
#
# Distance metric: L3, Accuracy +- sd: 0.48999999999999994 +- 0.03232070697205667
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.4963636363636364 +- 0.036972180741205014
#
# Distance metric: corr_coef, Accuracy +- sd: 0.47727272727272735 +- 0.07735289958611873
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.4790909090909092 +- 0.07377652205553993
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between date and juice for subject 5, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5372727272727273 +- 0.07504268757632342
#
# Distance metric: L2, Accuracy +- sd: 0.5381818181818181 +- 0.07138534701600209
#
# Distance metric: L3, Accuracy +- sd: 0.5081818181818182 +- 0.036972180741205014
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5218181818181818 +- 0.03394209945926268
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5118181818181817 +- 0.039688872641714695
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5163636363636364 +- 0.034449627857266206
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between hedgehog and waterfowl for subject 5, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5127272727272727 +- 0.09444925175471108
#
# Distance metric: L2, Accuracy +- sd: 0.5136363636363636 +- 0.08911873405929067
#
# Distance metric: L3, Accuracy +- sd: 0.509090909090909 +- 0.043026034786179036
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5036363636363637 +- 0.021780270092201705
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5345454545454545 +- 0.06927010255108634
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5372727272727273 +- 0.0664569704818075
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between juice and ambassador for subject 5, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.4918181818181818 +- 0.1059159186250198
#
# Distance metric: L2, Accuracy +- sd: 0.48 +- 0.08636842092009904
#
# Distance metric: L3, Accuracy +- sd: 0.5181818181818182 +- 0.03497342556667517
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5309090909090909 +- 0.022709083630539625
#
# Distance metric: corr_coef, Accuracy +- sd: 0.4645454545454545 +- 0.06073924759450933
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.4536363636363636 +- 0.06676714191628559
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between goose and moose for subject 5, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5190909090909092 +- 0.0794297860320101
#
# Distance metric: L2, Accuracy +- sd: 0.5045454545454546 +- 0.101476700090006
#
# Distance metric: L3, Accuracy +- sd: 0.5145454545454545 +- 0.040898988651643604
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.4963636363636364 +- 0.03871916261644881
#
# Distance metric: corr_coef, Accuracy +- sd: 0.52 +- 0.08492096471386724
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5190909090909092 +- 0.08693114973005032
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between moose and spruce for subject 5, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.4800000000000001 +- 0.07928398585605509
#
# Distance metric: L2, Accuracy +- sd: 0.46545454545454545 +- 0.06830897234243348
#
# Distance metric: L3, Accuracy +- sd: 0.5118181818181818 +- 0.02381054700674327
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.4918181818181818 +- 0.04179841430026416
#
# Distance metric: corr_coef, Accuracy +- sd: 0.500909090909091 +- 0.05280558447802764
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.49727272727272726 +- 0.05428726773394043
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between moose and caterpillar for subject 5, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5081818181818182 +- 0.07635281308580387
#
# Distance metric: L2, Accuracy +- sd: 0.4945454545454545 +- 0.058025357808119786
#
# Distance metric: L3, Accuracy +- sd: 0.5372727272727273 +- 0.028225772175018236
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.48 +- 0.030233252996937965
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5072727272727273 +- 0.044776764930999094
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5081818181818182 +- 0.051858038898006026
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between juice and waterfowl for subject 5, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5245454545454545 +- 0.0731013108835441
#
# Distance metric: L2, Accuracy +- sd: 0.5081818181818182 +- 0.07493247649089045
#
# Distance metric: L3, Accuracy +- sd: 0.5263636363636363 +- 0.027181666159501905
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.4618181818181818 +- 0.02516064091472372
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5154545454545454 +- 0.08636842092009907
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5136363636363637 +- 0.08430562268632459
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between hedgehog and goose for subject 5, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5281818181818181 +- 0.0362953905048675
#
# Distance metric: L2, Accuracy +- sd: 0.5327272727272728 +- 0.028078991293600898
#
# Distance metric: L3, Accuracy +- sd: 0.5609090909090908 +- 0.017391933154280892
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5009090909090909 +- 0.042775601294613066
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5436363636363636 +- 0.03820345707172853
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5381818181818181 +- 0.03927020193900941
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between night and knight for subject 5, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.54 +- 0.045399967233395525
#
# Distance metric: L2, Accuracy +- sd: 0.5418181818181818 +- 0.05296186059501639
#
# Distance metric: L3, Accuracy +- sd: 0.47000000000000003 +- 0.04230936828443673
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5081818181818182 +- 0.02377581241931277
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5872727272727273 +- 0.04940973906073161
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5909090909090909 +- 0.039626354032187935
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between date and juice for subject 5, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5909090909090908 +- 0.05012381364396444
#
# Distance metric: L2, Accuracy +- sd: 0.6081818181818182 +- 0.03490246149173178
#
# Distance metric: L3, Accuracy +- sd: 0.5372727272727273 +- 0.05991729837557848
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5072727272727272 +- 0.012398346997259859
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5909090909090909 +- 0.03770262064241404
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5863636363636363 +- 0.04350358586911054
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between hedgehog and waterfowl for subject 5, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.579090909090909 +- 0.07332707210936645
#
# Distance metric: L2, Accuracy +- sd: 0.5618181818181818 +- 0.07855092573537437
#
# Distance metric: L3, Accuracy +- sd: 0.5772727272727274 +- 0.05166644450321026
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5009090909090909 +- 0.03882573909829566
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5800000000000001 +- 0.07587506041769211
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5754545454545454 +- 0.07532848176678762
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between juice and ambassador for subject 5, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5345454545454544 +- 0.05367487061500186
#
# Distance metric: L2, Accuracy +- sd: 0.5309090909090909 +- 0.04160022250417291
#
# Distance metric: L3, Accuracy +- sd: 0.4945454545454545 +- 0.047097577625413146
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5118181818181818 +- 0.03221826390303518
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5672727272727273 +- 0.047966930757356065
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5736363636363636 +- 0.045762592540557166
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between goose and moose for subject 6, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5118181818181818 +- 0.04250425355476713
#
# Distance metric: L2, Accuracy +- sd: 0.5045454545454545 +- 0.03461715048119958
#
# Distance metric: L3, Accuracy +- sd: 0.5345454545454545 +- 0.02940174841599315
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5018181818181819 +- 0.03322848524090377
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5027272727272727 +- 0.028690425160108172
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5072727272727273 +- 0.0256486108721198
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between moose and spruce for subject 6, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.55 +- 0.05842279641112592
#
# Distance metric: L2, Accuracy +- sd: 0.5390909090909091 +- 0.061764682732592835
#
# Distance metric: L3, Accuracy +- sd: 0.5127272727272727 +- 0.010523488093445681
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.48818181818181816 +- 0.023636363636363643
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5190909090909092 +- 0.07143164102022981
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5218181818181817 +- 0.06762805423053561
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between moose and caterpillar for subject 6, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5281818181818182 +- 0.03606697168159524
#
# Distance metric: L2, Accuracy +- sd: 0.5236363636363637 +- 0.05943257864974964
#
# Distance metric: L3, Accuracy +- sd: 0.5363636363636364 +- 0.02603240193322974
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5172727272727273 +- 0.018044939310253808
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5127272727272727 +- 0.05153831921112132
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5136363636363637 +- 0.05253884827927231
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between juice and waterfowl for subject 6, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5545454545454545 +- 0.04481366379587723
#
# Distance metric: L2, Accuracy +- sd: 0.5281818181818181 +- 0.04169943614974442
#
# Distance metric: L3, Accuracy +- sd: 0.49909090909090914 +- 0.03763680280815357
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.49727272727272726 +- 0.04614028196527099
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5390909090909091 +- 0.0375488662328425
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5327272727272727 +- 0.030748244591432296
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between hedgehog and goose for subject 6, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5718181818181817 +- 0.042775601294613066
#
# Distance metric: L2, Accuracy +- sd: 0.610909090909091 +- 0.05937693015566522
#
# Distance metric: L3, Accuracy +- sd: 0.4963636363636364 +- 0.058167611901986875
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.4763636363636364 +- 0.04277560129461308
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5590909090909091 +- 0.05720775535473556
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5581818181818182 +- 0.053736424385933255
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between night and knight for subject 6, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5127272727272728 +- 0.021007672742347883
#
# Distance metric: L2, Accuracy +- sd: 0.5272727272727272 +- 0.02681432946136842
#
# Distance metric: L3, Accuracy +- sd: 0.5209090909090909 +- 0.05090909090909092
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.4827272727272727 +- 0.030613560437241335
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5181818181818182 +- 0.023879864611934008
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5200000000000001 +- 0.02751408354622103
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between date and juice for subject 6, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5390909090909091 +- 0.013047909176733935
#
# Distance metric: L2, Accuracy +- sd: 0.5072727272727272 +- 0.027961011816781275
#
# Distance metric: L3, Accuracy +- sd: 0.5018181818181817 +- 0.03699452718068327
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.49363636363636365 +- 0.02628514962691083
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5154545454545454 +- 0.05860640531376797
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.510909090909091 +- 0.056961637082983775
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between hedgehog and waterfowl for subject 6, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5227272727272727 +- 0.05604012729971796
#
# Distance metric: L2, Accuracy +- sd: 0.5127272727272727 +- 0.04049283172967289
#
# Distance metric: L3, Accuracy +- sd: 0.48999999999999994 +- 0.021203461435801107
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.49818181818181817 +- 0.04112066501054054
#
# Distance metric: corr_coef, Accuracy +- sd: 0.49818181818181817 +- 0.06243012623050687
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.4918181818181818 +- 0.0534279463815095
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between juice and ambassador for subject 6, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5418181818181818 +- 0.04089898865164361
#
# Distance metric: L2, Accuracy +- sd: 0.5236363636363637 +- 0.040797828495121584
#
# Distance metric: L3, Accuracy +- sd: 0.5372727272727273 +- 0.027181666159501912
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.509090909090909 +- 0.013787046261911918
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5518181818181819 +- 0.05195357113538019
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5481818181818181 +- 0.04550905822103209
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between goose and moose for subject 6, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5199999999999999 +- 0.03272727272727272
#
# Distance metric: L2, Accuracy +- sd: 0.5136363636363637 +- 0.047499456282229555
#
# Distance metric: L3, Accuracy +- sd: 0.4945454545454545 +- 0.026875900907444506
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.48909090909090913 +- 0.03586015076966549
#
# Distance metric: corr_coef, Accuracy +- sd: 0.48090909090909095 +- 0.0818383813449229
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.48090909090909095 +- 0.08259229748170095
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between moose and spruce for subject 6, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5127272727272727 +- 0.028371793698776793
#
# Distance metric: L2, Accuracy +- sd: 0.5045454545454545 +- 0.04793245936896024
#
# Distance metric: L3, Accuracy +- sd: 0.4845454545454545 +- 0.03396643944048981
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.49727272727272726 +- 0.01809068067466581
#
# Distance metric: corr_coef, Accuracy +- sd: 0.51 +- 0.0389320238279343
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5072727272727273 +- 0.03432946834272581
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between moose and caterpillar for subject 6, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5863636363636363 +- 0.050779054704614336
#
# Distance metric: L2, Accuracy +- sd: 0.6018181818181818 +- 0.03372224907452984
#
# Distance metric: L3, Accuracy +- sd: 0.5281818181818181 +- 0.051937661298493455
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5172727272727273 +- 0.021397458719890586
#
# Distance metric: corr_coef, Accuracy +- sd: 0.6027272727272728 +- 0.04250425355476715
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.599090909090909 +- 0.04018552019145517
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between juice and waterfowl for subject 6, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5890909090909091 +- 0.056816363607271825
#
# Distance metric: L2, Accuracy +- sd: 0.5809090909090908 +- 0.04008255942736112
#
# Distance metric: L3, Accuracy +- sd: 0.5254545454545454 +- 0.020849718074872212
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5290909090909091 +- 0.02237915204562033
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5890909090909091 +- 0.04412604036186035
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5745454545454546 +- 0.040308725958900664
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between hedgehog and goose for subject 6, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.4781818181818182 +- 0.045762592540557166
#
# Distance metric: L2, Accuracy +- sd: 0.4918181818181818 +- 0.048224680763181246
#
# Distance metric: L3, Accuracy +- sd: 0.4918181818181818 +- 0.036972180741204994
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5009090909090909 +- 0.012331509060227754
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5118181818181818 +- 0.035512772699317456
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5063636363636363 +- 0.0392702019390094
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between night and knight for subject 6, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5818181818181818 +- 0.036702962251247896
#
# Distance metric: L2, Accuracy +- sd: 0.5836363636363637 +- 0.05761083461001767
#
# Distance metric: L3, Accuracy +- sd: 0.5390909090909091 +- 0.02004127971368059
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5045454545454545 +- 0.04626549327272536
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5845454545454546 +- 0.02644189013136179
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5754545454545454 +- 0.0326007655946202
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between date and juice for subject 6, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5299999999999999 +- 0.05398193759746734
#
# Distance metric: L2, Accuracy +- sd: 0.5154545454545454 +- 0.05258601768719846
#
# Distance metric: L3, Accuracy +- sd: 0.5127272727272727 +- 0.040999899213744306
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.48 +- 0.034807617671048466
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5463636363636363 +- 0.043541563690283815
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5436363636363637 +- 0.046939384157911206
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between hedgehog and waterfowl for subject 6, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.4836363636363636 +- 0.05242862129198623
#
# Distance metric: L2, Accuracy +- sd: 0.4872727272727272 +- 0.06346730791166204
#
# Distance metric: L3, Accuracy +- sd: 0.4818181818181818 +- 0.01548126033266035
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5 +- 0.011853095282186622
#
# Distance metric: corr_coef, Accuracy +- sd: 0.4481818181818181 +- 0.039688872641714695
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.46454545454545454 +- 0.044107307166211654
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between juice and ambassador for subject 6, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5409090909090908 +- 0.06485839629722533
#
# Distance metric: L2, Accuracy +- sd: 0.5554545454545454 +- 0.07309000451724283
#
# Distance metric: L3, Accuracy +- sd: 0.5390909090909091 +- 0.04412604036186034
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.4827272727272727 +- 0.011642044068059718
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5309090909090909 +- 0.06805442644441055
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5427272727272727 +- 0.07057028616391037
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between goose and moose for subject 7, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5972727272727273 +- 0.04162008415367127
#
# Distance metric: L2, Accuracy +- sd: 0.5945454545454545 +- 0.04316028171079717
#
# Distance metric: L3, Accuracy +- sd: 0.5245454545454545 +- 0.025968830649246717
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.4836363636363637 +- 0.013965719541579281
#
# Distance metric: corr_coef, Accuracy +- sd: 0.6172727272727272 +- 0.045581640497169736
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.6163636363636364 +- 0.045235837471362665
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between moose and spruce for subject 7, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.7654545454545454 +- 0.07439008198355923
#
# Distance metric: L2, Accuracy +- sd: 0.760909090909091 +- 0.05266453948349176
#
# Distance metric: L3, Accuracy +- sd: 0.6063636363636362 +- 0.05811075205271598
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.4590909090909091 +- 0.037150575894004646
#
# Distance metric: corr_coef, Accuracy +- sd: 0.7545454545454545 +- 0.061858275768014524
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.7509090909090909 +- 0.06208498574168682
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between moose and caterpillar for subject 7, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.6300000000000001 +- 0.0551931244969474
#
# Distance metric: L2, Accuracy +- sd: 0.650909090909091 +- 0.030342398669597506
#
# Distance metric: L3, Accuracy +- sd: 0.5245454545454545 +- 0.028546033578377417
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.4827272727272727 +- 0.030068791651893145
#
# Distance metric: corr_coef, Accuracy +- sd: 0.6381818181818182 +- 0.027059774665704032
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.6336363636363637 +- 0.02328408813611947
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between juice and waterfowl for subject 7, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.54 +- 0.04621187282595939
#
# Distance metric: L2, Accuracy +- sd: 0.5518181818181818 +- 0.06109199133240526
#
# Distance metric: L3, Accuracy +- sd: 0.48636363636363633 +- 0.0295978556292722
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5272727272727272 +- 0.04590684062891854
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5399999999999999 +- 0.05495302276257242
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5390909090909091 +- 0.05688904671695279
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between hedgehog and goose for subject 7, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.6063636363636363 +- 0.04523583747136265
#
# Distance metric: L2, Accuracy +- sd: 0.6054545454545455 +- 0.04762109401348654
#
# Distance metric: L3, Accuracy +- sd: 0.5254545454545455 +- 0.009791208740244545
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5145454545454545 +- 0.013298853489388904
#
# Distance metric: corr_coef, Accuracy +- sd: 0.6154545454545455 +- 0.05017325355107864
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.6118181818181819 +- 0.049342788164043305
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between night and knight for subject 7, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5818181818181818 +- 0.0792527080643759
#
# Distance metric: L2, Accuracy +- sd: 0.5845454545454545 +- 0.06571916207973755
#
# Distance metric: L3, Accuracy +- sd: 0.49818181818181817 +- 0.039999999999999994
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.4827272727272727 +- 0.012662171161076465
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5963636363636364 +- 0.05943257864974967
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5872727272727273 +- 0.06215150776413532
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between date and juice for subject 7, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5563636363636364 +- 0.02612746884218165
#
# Distance metric: L2, Accuracy +- sd: 0.5809090909090909 +- 0.04354156369028378
#
# Distance metric: L3, Accuracy +- sd: 0.49727272727272726 +- 0.0362041959122543
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.4954545454545455 +- 0.04302603478617902
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5790909090909091 +- 0.03130759155949557
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5772727272727274 +- 0.034015067152490364
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between hedgehog and waterfowl for subject 7, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5972727272727273 +- 0.06521420521622165
#
# Distance metric: L2, Accuracy +- sd: 0.5863636363636363 +- 0.030424000964875502
#
# Distance metric: L3, Accuracy +- sd: 0.5072727272727272 +- 0.03260076559462018
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.4836363636363636 +- 0.03272727272727273
#
# Distance metric: corr_coef, Accuracy +- sd: 0.6036363636363636 +- 0.04248480525653791
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.6027272727272728 +- 0.03916483496097823
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between juice and ambassador for subject 7, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.590909090909091 +- 0.0775662873007329
#
# Distance metric: L2, Accuracy +- sd: 0.5918181818181818 +- 0.06853846118171189
#
# Distance metric: L3, Accuracy +- sd: 0.4963636363636364 +- 0.035605738231938425
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.510909090909091 +- 0.05443929062392677
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5945454545454545 +- 0.05495302276257242
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5936363636363636 +- 0.05681636360727178
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between goose and moose for subject 7, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5781818181818182 +- 0.04179841430026417
#
# Distance metric: L2, Accuracy +- sd: 0.5709090909090909 +- 0.032089750172223264
#
# Distance metric: L3, Accuracy +- sd: 0.5409090909090908 +- 0.038995655617322204
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.48545454545454547 +- 0.016109131951517572
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5909090909090909 +- 0.0544696442870736
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5854545454545454 +- 0.0637920174285412
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between moose and spruce for subject 7, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.7627272727272727 +- 0.08168676314267369
#
# Distance metric: L2, Accuracy +- sd: 0.7736363636363637 +- 0.0809754579696122
#
# Distance metric: L3, Accuracy +- sd: 0.6799999999999999 +- 0.07636363636363634
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.4909090909090909 +- 0.017248787237282074
#
# Distance metric: corr_coef, Accuracy +- sd: 0.7390909090909091 +- 0.07722458393307381
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.7427272727272728 +- 0.07834022008294736
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between moose and caterpillar for subject 7, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5590909090909091 +- 0.035208939510976534
#
# Distance metric: L2, Accuracy +- sd: 0.5536363636363636 +- 0.05097398461409522
#
# Distance metric: L3, Accuracy +- sd: 0.5599999999999999 +- 0.039875840362656935
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.48636363636363633 +- 0.03162277660168379
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5818181818181818 +- 0.06827266674734031
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5836363636363636 +- 0.07033567685048983
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between juice and waterfowl for subject 7, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5063636363636363 +- 0.04171925056575918
#
# Distance metric: L2, Accuracy +- sd: 0.5318181818181819 +- 0.03555928584655989
#
# Distance metric: L3, Accuracy +- sd: 0.5145454545454545 +- 0.031148803089112387
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5090909090909091 +- 0.019069251784911846
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5263636363636364 +- 0.04594283188543009
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5245454545454546 +- 0.04365529892197442
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between hedgehog and goose for subject 7, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5645454545454546 +- 0.04915820303489373
#
# Distance metric: L2, Accuracy +- sd: 0.5636363636363637 +- 0.06009634138559422
#
# Distance metric: L3, Accuracy +- sd: 0.4781818181818182 +- 0.02496278221408358
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5009090909090909 +- 0.026566616720368114
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5690909090909091 +- 0.07974131730759414
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5727272727272728 +- 0.07546002170708048
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between night and knight for subject 7, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5245454545454545 +- 0.052742944379491966
#
# Distance metric: L2, Accuracy +- sd: 0.5390909090909091 +- 0.07461194374066615
#
# Distance metric: L3, Accuracy +- sd: 0.4945454545454545 +- 0.04603268691335333
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.4818181818181818 +- 0.02619065507434169
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5318181818181819 +- 0.05982066864131673
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5390909090909091 +- 0.05846521887568555
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between date and juice for subject 7, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5881818181818181 +- 0.09861017666624858
#
# Distance metric: L2, Accuracy +- sd: 0.5836363636363636 +- 0.09134441226967617
#
# Distance metric: L3, Accuracy +- sd: 0.5163636363636364 +- 0.05674358739755359
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.4836363636363637 +- 0.03574473318425002
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5572727272727274 +- 0.03130759155949557
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5572727272727273 +- 0.03884701930767542
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between hedgehog and waterfowl for subject 7, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.6781818181818181 +- 0.044665885441957244
#
# Distance metric: L2, Accuracy +- sd: 0.6818181818181819 +- 0.044443296587564796
#
# Distance metric: L3, Accuracy +- sd: 0.5436363636363637 +- 0.035512772699317484
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5072727272727273 +- 0.051794252848160395
#
# Distance metric: corr_coef, Accuracy +- sd: 0.6427272727272728 +- 0.056597754240994134
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.6463636363636363 +- 0.05584808201239155
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between juice and ambassador for subject 7, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.6345454545454545 +- 0.07818181818181819
#
# Distance metric: L2, Accuracy +- sd: 0.6372727272727272 +- 0.06564366617649348
#
# Distance metric: L3, Accuracy +- sd: 0.5854545454545456 +- 0.036747968966195886
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.4981818181818182 +- 0.0046354722850843405
#
# Distance metric: corr_coef, Accuracy +- sd: 0.6027272727272728 +- 0.0829019135649309
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.6045454545454547 +- 0.07665528721393743
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between goose and moose for subject 8, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5718181818181819 +- 0.06181818181818182
#
# Distance metric: L2, Accuracy +- sd: 0.56 +- 0.08650228105720204
#
# Distance metric: L3, Accuracy +- sd: 0.5563636363636364 +- 0.030233252996937993
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.4663636363636363 +- 0.01666391161802125
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5536363636363636 +- 0.10386736615542974
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5545454545454546 +- 0.10208568755367123
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between moose and spruce for subject 8, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5018181818181817 +- 0.05066499924761008
#
# Distance metric: L2, Accuracy +- sd: 0.5327272727272727 +- 0.04521756405616684
#
# Distance metric: L3, Accuracy +- sd: 0.5318181818181819 +- 0.04767312946227961
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5199999999999999 +- 0.0351619629196613
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5209090909090909 +- 0.02548699230704763
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5172727272727273 +- 0.024796693994519736
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between moose and caterpillar for subject 8, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.49909090909090903 +- 0.015850541612875163
#
# Distance metric: L2, Accuracy +- sd: 0.4718181818181818 +- 0.036747968966195865
#
# Distance metric: L3, Accuracy +- sd: 0.5181818181818183 +- 0.05110352480929161
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.49909090909090914 +- 0.019370250684238626
#
# Distance metric: corr_coef, Accuracy +- sd: 0.4818181818181818 +- 0.025873180855923106
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.47545454545454546 +- 0.02381054700674327
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between juice and waterfowl for subject 8, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5490909090909091 +- 0.06340216645150071
#
# Distance metric: L2, Accuracy +- sd: 0.52 +- 0.06708819900907306
#
# Distance metric: L3, Accuracy +- sd: 0.4909090909090909 +- 0.023706190564373276
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5045454545454545 +- 0.032903565583370646
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5590909090909091 +- 0.0661203510762479
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5654545454545455 +- 0.056231516706153145
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between hedgehog and goose for subject 8, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.6136363636363636 +- 0.05355155081826598
#
# Distance metric: L2, Accuracy +- sd: 0.6327272727272728 +- 0.06101076994750006
#
# Distance metric: L3, Accuracy +- sd: 0.5563636363636364 +- 0.026752616308294824
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.500909090909091 +- 0.022890324203662115
#
# Distance metric: corr_coef, Accuracy +- sd: 0.6245454545454545 +- 0.05652469656985385
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.6218181818181818 +- 0.05816761190198684
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between night and knight for subject 8, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.4954545454545454 +- 0.06064392756421061
#
# Distance metric: L2, Accuracy +- sd: 0.5045454545454546 +- 0.048361585739165054
#
# Distance metric: L3, Accuracy +- sd: 0.5418181818181818 +- 0.029513969237723522
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.48909090909090913 +- 0.035161962919661297
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5427272727272727 +- 0.060752852533104085
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5381818181818182 +- 0.05405843180843095
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between date and juice for subject 8, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5172727272727273 +- 0.03357488238658071
#
# Distance metric: L2, Accuracy +- sd: 0.4972727272727272 +- 0.022926400387124506
#
# Distance metric: L3, Accuracy +- sd: 0.47545454545454546 +- 0.01691006839794389
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.49000000000000005 +- 0.02718166615950192
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5363636363636364 +- 0.024223477444498594
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5209090909090909 +- 0.02897704991001677
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between hedgehog and waterfowl for subject 8, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5181818181818182 +- 0.0694726297256102
#
# Distance metric: L2, Accuracy +- sd: 0.5381818181818182 +- 0.0913896389953614
#
# Distance metric: L3, Accuracy +- sd: 0.4963636363636364 +- 0.04932603624091106
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.48818181818181816 +- 0.0183176742541908
#
# Distance metric: corr_coef, Accuracy +- sd: 0.53 +- 0.08169687977694896
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5254545454545455 +- 0.0721912061676066
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between juice and ambassador for subject 8, imagined
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5063636363636363 +- 0.061227120874482656
#
# Distance metric: L2, Accuracy +- sd: 0.48545454545454547 +- 0.048395751469840605
#
# Distance metric: L3, Accuracy +- sd: 0.49000000000000005 +- 0.02178027009220171
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.51 +- 0.03167500252760792
#
# Distance metric: corr_coef, Accuracy +- sd: 0.4945454545454545 +- 0.05495302276257242
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.4954545454545454 +- 0.05507320447585802
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between goose and moose for subject 8, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5627272727272727 +- 0.047272727272727265
#
# Distance metric: L2, Accuracy +- sd: 0.5599999999999999 +- 0.05547689564506312
#
# Distance metric: L3, Accuracy +- sd: 0.5045454545454545 +- 0.03042400096487548
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.49727272727272726 +- 0.03665790027937447
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5445454545454546 +- 0.0426788894338382
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5509090909090909 +- 0.04120097888590783
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between moose and spruce for subject 8, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5318181818181819 +- 0.032397326693100845
#
# Distance metric: L2, Accuracy +- sd: 0.5345454545454545 +- 0.02825503685076374
#
# Distance metric: L3, Accuracy +- sd: 0.5009090909090909 +- 0.034664865390795656
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5236363636363637 +- 0.01710444338384251
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5445454545454546 +- 0.05381326758890453
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5463636363636364 +- 0.05040333191137859
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between moose and caterpillar for subject 8, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5254545454545454 +- 0.04523583747136266
#
# Distance metric: L2, Accuracy +- sd: 0.530909090909091 +- 0.03618136134933164
#
# Distance metric: L3, Accuracy +- sd: 0.5254545454545455 +- 0.03335261150517118
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.4954545454545455 +- 0.04175885119220311
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5363636363636364 +- 0.04626549327272536
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5409090909090908 +- 0.046621386927120305
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between juice and waterfowl for subject 8, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5318181818181819 +- 0.029737140425083845
#
# Distance metric: L2, Accuracy +- sd: 0.5581818181818182 +- 0.03193485103681872
#
# Distance metric: L3, Accuracy +- sd: 0.5363636363636364 +- 0.05492293624361167
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5054545454545455 +- 0.021007672742347886
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5545454545454545 +- 0.061858275768014524
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5527272727272727 +- 0.06367531275577261
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between hedgehog and goose for subject 8, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.520909090909091 +- 0.05881754952589749
#
# Distance metric: L2, Accuracy +- sd: 0.5572727272727274 +- 0.04587082113288313
#
# Distance metric: L3, Accuracy +- sd: 0.5227272727272727 +- 0.04775972922386799
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.46818181818181814 +- 0.01748671278333758
#
# Distance metric: corr_coef, Accuracy +- sd: 0.55 +- 0.06643209420525495
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5472727272727272 +- 0.0719618815533211
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between night and knight for subject 8, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.4818181818181818 +- 0.06043916414034419
#
# Distance metric: L2, Accuracy +- sd: 0.4663636363636364 +- 0.029681504940571826
#
# Distance metric: L3, Accuracy +- sd: 0.49363636363636365 +- 0.030096264285903375
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.4909090909090909 +- 0.039312269655344824
#
# Distance metric: corr_coef, Accuracy +- sd: 0.4827272727272727 +- 0.017580981459830655
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.48818181818181816 +- 0.01060173071790055
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between date and juice for subject 8, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.4727272727272728 +- 0.007041787902195305
#
# Distance metric: L2, Accuracy +- sd: 0.48545454545454547 +- 0.02748402992332906
#
# Distance metric: L3, Accuracy +- sd: 0.48545454545454547 +- 0.04079782849512159
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.5072727272727272 +- 0.04030872595890066
#
# Distance metric: corr_coef, Accuracy +- sd: 0.47363636363636363 +- 0.02139745871989058
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.4763636363636364 +- 0.02496278221408362
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between hedgehog and waterfowl for subject 8, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.5127272727272727 +- 0.024120907566221088
#
# Distance metric: L2, Accuracy +- sd: 0.51 +- 0.030613560437241352
#
# Distance metric: L3, Accuracy +- sd: 0.4945454545454545 +- 0.05073020519383168
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.510909090909091 +- 0.02736348535144074
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5081818181818182 +- 0.03663534850838161
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.5118181818181818 +- 0.034688698233343494
#
# ================================================================================================
# 5 fold Cross-validated accuracies KNN Binary classification between juice and ambassador for subject 8, inner
# -------------------------------------------------------------------------
# Distance metric: L4, Accuracy +- sd: 0.49727272727272726 +- 0.05489283323436555
#
# Distance metric: L2, Accuracy +- sd: 0.5045454545454545 +- 0.0637661015154552
#
# Distance metric: L3, Accuracy +- sd: 0.5263636363636364 +- 0.05327303754175857
#
# Distance metric: chi2_distance, Accuracy +- sd: 0.48 +- 0.022193737483152173
#
# Distance metric: corr_coef, Accuracy +- sd: 0.5009090909090909 +- 0.052254937684363324
#
# Distance metric: spatial_dist, Accuracy +- sd: 0.49363636363636365 +- 0.053828623065772595

# %%
knn_metric_accs[:, :, :, 0].shape
# Out:
# (4, 2, 9)

# %%
knn_metric_accs.shape
# Out:
# (4, 2, 9, 6)

# %%
knn_metric_accs[0][:, 0,3]
# Out:
# array([0.50363636, 0.49636364])

# %%
knn_accs = np.mean(np.mean(knn_metric_accs, axis = 0), axis = 0)

# %%
knn_sds = np.mean(np.mean(knn_metric_stds, axis = 0), axis = 0)

# %%
for i, row in enumerate(knn_accs):
    print('& {:.2f} $\\pm$ {:.2f} & {:.2f} $\\pm$ {:.2f} & {:.2f} $\\pm$ {:.2f} & {:.2f} $\\pm$ {:.2f} & {:.2f} $\\pm$ {:.2f} & {:.2f} $\\pm$ {:.2f} \\\\'.format(row[0], knn_sds[i][0],row[1], knn_sds[i][1],row[2], knn_sds[i][2], row[3], knn_sds[i][3], row[4], knn_sds[i][4], row[5], knn_sds[i][5]))
# Out:
# & 0.55 $\pm$ 0.05 & 0.54 $\pm$ 0.06 & 0.52 $\pm$ 0.03 & 0.49 $\pm$ 0.03 & 0.54 $\pm$ 0.07 & 0.54 $\pm$ 0.07 \\
# & 0.59 $\pm$ 0.05 & 0.59 $\pm$ 0.05 & 0.55 $\pm$ 0.04 & 0.50 $\pm$ 0.03 & 0.58 $\pm$ 0.05 & 0.58 $\pm$ 0.05 \\
# & 0.56 $\pm$ 0.05 & 0.55 $\pm$ 0.05 & 0.54 $\pm$ 0.03 & 0.49 $\pm$ 0.03 & 0.56 $\pm$ 0.04 & 0.55 $\pm$ 0.04 \\
# & 0.54 $\pm$ 0.05 & 0.54 $\pm$ 0.05 & 0.51 $\pm$ 0.03 & 0.50 $\pm$ 0.03 & 0.55 $\pm$ 0.05 & 0.54 $\pm$ 0.05 \\
# & 0.55 $\pm$ 0.05 & 0.56 $\pm$ 0.05 & 0.52 $\pm$ 0.03 & 0.49 $\pm$ 0.03 & 0.56 $\pm$ 0.06 & 0.56 $\pm$ 0.06 \\
# & 0.52 $\pm$ 0.06 & 0.53 $\pm$ 0.06 & 0.51 $\pm$ 0.04 & 0.49 $\pm$ 0.03 & 0.54 $\pm$ 0.05 & 0.54 $\pm$ 0.04 \\
# & 0.54 $\pm$ 0.04 & 0.54 $\pm$ 0.05 & 0.50 $\pm$ 0.04 & 0.50 $\pm$ 0.03 & 0.54 $\pm$ 0.04 & 0.54 $\pm$ 0.04 \\
# & 0.55 $\pm$ 0.06 & 0.55 $\pm$ 0.06 & 0.51 $\pm$ 0.04 & 0.50 $\pm$ 0.03 & 0.54 $\pm$ 0.06 & 0.54 $\pm$ 0.06 \\
# & 0.54 $\pm$ 0.07 & 0.54 $\pm$ 0.06 & 0.52 $\pm$ 0.04 & 0.50 $\pm$ 0.02 & 0.54 $\pm$ 0.06 & 0.54 $\pm$ 0.06 \\

# %%
knn_metric_accs.shape
# Out:
# (4, 2, 9, 6)

# %%
np.mean(np.mean(knn_metric_accs, axis=2), axis = 1)
# Out:
# array([[0.53222222, 0.52833333, 0.52121212, 0.49651515, 0.53161616,
#         0.53080808],
#        [0.53641414, 0.5339899 , 0.51257576, 0.49808081, 0.52893939,
#         0.52772727],
#        [0.60343434, 0.60792929, 0.53222222, 0.49353535, 0.60449495,
#         0.60383838],
#        [0.52277778, 0.525     , 0.51373737, 0.49707071, 0.52994949,
#         0.5290404 ]])

# %%
sd=  np.mean(np.mean(knn_metric_stds, axis=2), axis = 1).T
for i, row in enumerate(np.mean(np.mean(knn_metric_accs, axis=2), axis = 1).T):
    print('&{:.4f} $\\pm$ {:.4f} & {:.4f} $\\pm$ {:.4f} & {:.4f} $\\pm$ {:.4f} & {:.4f} $\\pm$ {:.4f}\\\\'.format(row[0],sd[i][0], row[1],sd[i][1], row[2],sd[i][2], row[3],sd[i][3]))
# Out:
# &0.5322 $\pm$ 0.0676 & 0.5364 $\pm$ 0.0432 & 0.6034 $\pm$ 0.0575 & 0.5228 $\pm$ 0.0461\\
# &0.5283 $\pm$ 0.0672 & 0.5340 $\pm$ 0.0476 & 0.6079 $\pm$ 0.0544 & 0.5250 $\pm$ 0.0476\\
# &0.5212 $\pm$ 0.0363 & 0.5126 $\pm$ 0.0327 & 0.5322 $\pm$ 0.0379 & 0.5137 $\pm$ 0.0374\\
# &0.4965 $\pm$ 0.0303 & 0.4981 $\pm$ 0.0272 & 0.4935 $\pm$ 0.0285 & 0.4971 $\pm$ 0.0279\\
# &0.5316 $\pm$ 0.0583 & 0.5289 $\pm$ 0.0480 & 0.6045 $\pm$ 0.0547 & 0.5299 $\pm$ 0.0499\\
# &0.5308 $\pm$ 0.0572 & 0.5277 $\pm$ 0.0469 & 0.6038 $\pm$ 0.0550 & 0.5290 $\pm$ 0.0485\\

# %%
np.mean(np.mean(knn_metric_stds, axis=2), axis = 1)[0]
# Out:
# array([0.06761234, 0.06724207, 0.0363186 , 0.03031443, 0.0583314 ,
#        0.05721514])

# %%
np.mean(np.mean(knn_metric_accs, axis=2), axis = 1).T
# Out:
# array([[0.53222222, 0.53641414, 0.60343434, 0.52277778],
#        [0.52833333, 0.5339899 , 0.60792929, 0.525     ],
#        [0.52121212, 0.51257576, 0.53222222, 0.51373737],
#        [0.49651515, 0.49808081, 0.49353535, 0.49707071],
#        [0.53161616, 0.52893939, 0.60449495, 0.52994949],
#        [0.53080808, 0.52772727, 0.60383838, 0.5290404 ]])
